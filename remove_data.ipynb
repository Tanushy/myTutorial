# %%
import pandas as pd
import numpy as np
df = pd.read_csv("./CSV-Files/Portfolio11.11.2022.csv")
df
# Out:
#                                Produkt   Symbol/ISIN  Anzahl Schlußkurs  \
# 0    CASH & CASH FUND & FTX CASH (EUR)           NaN     NaN        NaN
# 1                         2G ENERGY AG  DE000A0HL8N9    52.0      22,75
# 2                            ADESSO AG  DE000A0Z23Q5    10.0     111,00
# 3              ALPHABET INC. - CLASS A  US02079K3059    30.0      93,94
# 4                   ANN C50.00 16DEC22  DE000C6K9MB6     1.0       0,01
# 5                ARTHUR J. GALLAGHER &  US3635761097    27.0     193,00
# 6                   AS1 C30.00 16DEC22  FREN00676717     1.0       0,09
# 7               AVANZA BANK HOLDING AB  SE0012454072    50.0     237,00
# 8               BANK NOVA SCOTIA HALIF  CA0641491075    50.0      51,81
# 9                CARL ZEISS MEDITEC AG  DE0005313704    15.0     129,25
# 10              CME GROUP INC. - CLASS  US12572Q1058    15.0     174,34
# 11               DERMAPHARM HOLDING SE  DE000A2GS5D8    50.0      43,92
# ...

# %%
ind = 0
for item in df['Produkt']:
    tmp = item.split(' ')
    if tmp[0] == 'ISHARES':
        df.drop(index=ind, inplace=True)
    if tmp[0] == 'ODAX':
        df.drop(index=ind, inplace=True)
    if tmp[0] == 'ISHR':
        df.drop(index=ind, inplace=True)
    if tmp[0] == 'ANN':
        df.drop(index=ind, inplace=True)
    if tmp[0] == 'AS1':
        df.drop(index=ind, inplace=True)
    if tmp[0] == 'GENERAL':
        df.drop(index=ind, inplace=True)
    if tmp[0] == 'CASH':
        df.drop(index=ind, inplace=True)
    if tmp[0] == 'VANGUARD':
        df.drop(index=ind, inplace=True)
    ind += 1
df
# Out:
#                          Produkt   Symbol/ISIN  Anzahl Schlußkurs  \
# 1                   2G ENERGY AG  DE000A0HL8N9    52.0      22,75
# 2                      ADESSO AG  DE000A0Z23Q5    10.0     111,00
# 3        ALPHABET INC. - CLASS A  US02079K3059    30.0      93,94
# 5          ARTHUR J. GALLAGHER &  US3635761097    27.0     193,00
# 7         AVANZA BANK HOLDING AB  SE0012454072    50.0     237,00
# 8         BANK NOVA SCOTIA HALIF  CA0641491075    50.0      51,81
# 9          CARL ZEISS MEDITEC AG  DE0005313704    15.0     129,25
# 10        CME GROUP INC. - CLASS  US12572Q1058    15.0     174,34
# 11         DERMAPHARM HOLDING SE  DE000A2GS5D8    50.0      43,92
# 12            DEUTSCHE BOERSE AG  DE0005810055    20.0     163,30
# 13                DINO POLSKA SA  PLDINPL00011    75.0     343,00
# 14                      DNB BANK  NO0010161896   130.0     184,25
# 15        FIRST REPUBLIC BANK CO  US33616C1009    10.0     126,49
# ...

# %%
# Berechnung der Summe in EUR
summe = 0
for item in df['Wert in EUR']:
    summe += float(item.split(',')[0])
summe
# Out:
# 72664.0

# %%
def remove_row(dataset, name):
    ind = 0
    for item in dataset['Produkt']:
        if item == name:
            dataset.drop(index=ind, inplace=True)
        ind += 1

# %%
remove_row(df, 'ADESSO AG')

# %%
remove_row(df, '2G ENERGY AG')

# %%
df
# Out:
#                                Produkt   Symbol/ISIN  Anzahl Schlußkurs  \
# 0    CASH & CASH FUND & FTX CASH (EUR)           NaN     NaN        NaN
# 3              ALPHABET INC. - CLASS A  US02079K3059    30.0      93,94
# 4                   ANN C50.00 16DEC22  DE000C6K9MB6     1.0       0,01
# 5                ARTHUR J. GALLAGHER &  US3635761097    27.0     193,00
# 6                   AS1 C30.00 16DEC22  FREN00676717     1.0       0,09
# 7               AVANZA BANK HOLDING AB  SE0012454072    50.0     237,00
# 8               BANK NOVA SCOTIA HALIF  CA0641491075    50.0      51,81
# 9                CARL ZEISS MEDITEC AG  DE0005313704    15.0     129,25
# 10              CME GROUP INC. - CLASS  US12572Q1058    15.0     174,34
# 11               DERMAPHARM HOLDING SE  DE000A2GS5D8    50.0      43,92
# 12                  DEUTSCHE BOERSE AG  DE0005810055    20.0     163,30
# 13                      DINO POLSKA SA  PLDINPL00011    75.0     343,00
# ...
