# %%
import pandas as pd
import numpy as np

# %%
d = {'a': (1, 101), 'b': (2, 202), 'c': (3, 303)}
pd.DataFrame.from_dict(d, orient="index")
#df.to_csv("./CSV-Files/data.csv")

# %%
df = pd.read_csv("./CSV-Files/Portfolio.csv")
d = df.to_dict()

# %%
df_tmp = df[['Produkt','Wert']]
liste = [df['Produkt'], df['Wert']]
float(liste[1][0].split(' ')[1])
df_tmp[['Produkt','Wert']]

# %%
test = df.drop(index=0, inplace=False )
test

# %%
liste.pop(liste.index(input()))

# %%
for i in range(len(liste)):
    tmp = liste[i].split(' ')
    if tmp[0] == 'ISHARES':
        liste.append(liste[i])
    if tmp[0] == 'ODAX':
        liste.append(liste[i])
liste

# %%
ind = 0
for item in df['Produkt']:
    tmp = item.split(' ')
    if tmp[0] == 'ISHARES':
        df.drop(index=ind, inplace=True)
    if tmp[0] == 'ODAX':
        df.drop(index=ind, inplace=True)
    ind += 1
df

# %%
def remove_row():

# %%
for i in range(10):
    print(df_tmp['Produkt'][i].split(' ')[0])

# %%
for i in range(len(df_tmp['Produkt'])):
    df_tmp1 = df_tmp['Produkt'][i].split(' ')[0] == 'ISHARES'
    print(df_tmp1)

# %%
def remove_row():
    ind = 0
    for item in df['Produkt']:
        tmp = item.split(' ')
        if tmp[0] == 'ISHARES':
            df.drop(index=ind, inplace=True)
        if tmp[0] == 'ODAX':
            df.drop(index=ind, inplace=True)
        if tmp[0] == 'ISHR':
            df.drop(index=ind, inplace=True)
        if tmp[0] == 'ANN':
            df.drop(index=ind, inplace=True)
        if tmp[0] == 'AS1':
            df.drop(index=ind, inplace=True)
        if tmp[0] == 'GENERAL':
            df.drop(index=ind, inplace=True)
        if tmp[0] == 'VANGUARD':
            df.drop(index=ind, inplace=True)
        if tmp[0] == 'CASH':
            df.drop(index=ind, inplace=True)
        ind += 1

# %%
remove_list = ['ISHARES', 'ODAX', 'ISHR', 'VANGUARD']
ind = 0
for item in df['Produkt']:
    tmp = item.split(' ')
    if tmp[0] == remove_list[0]:
        df.drop(index=ind, inplace=True)
    if tmp[0] == remove_list[1]:
        df.drop(index=ind, inplace=True)
    ind += 1

# %%
df
# Out:
#                                Produkt   Symbol/ISIN  Anzahl Schlußkurs  \
# 0    CASH & CASH FUND & FTX CASH (EUR)           NaN     NaN        NaN
# 1                         2G ENERGY AG  DE000A0HL8N9    52.0      23,10
# 2                            ADESSO AG  DE000A0Z23Q5    10.0     102,00
# 3              ALPHABET INC. - CLASS A  US02079K3059    20.0      96,29
# 4                   ANN C50.00 16DEC22  DE000C6K9MB6     1.0       0,01
# 5                ARTHUR J. GALLAGHER &  US3635761097    27.0     188,58
# 6                   AS1 C30.00 16DEC22  FREN00676717     1.0       0,01
# 7               AVANZA BANK HOLDING AB  SE0012454072    50.0     224,10
# 8               BANK NOVA SCOTIA HALIF  CA0641491075    50.0      48,64
# 9                CARL ZEISS MEDITEC AG  DE0005313704    15.0     119,55
# 10              CME GROUP INC. - CLASS  US12572Q1058    15.0     174,75
# 11               DERMAPHARM HOLDING SE  DE000A2GS5D8    50.0      38,22
# ...

# %%
etwas = 'Hallo.dsv'
etwas = etwas[:-4] + '1' + '.dsv'
etwas
# Out:
# 'Hallo1.dsv'
